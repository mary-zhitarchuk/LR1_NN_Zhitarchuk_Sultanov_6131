# %% [markdown]
# <a href="https://colab.research.google.com/github/mary-zhitarchuk/LR1_NN_Zhitarchuk_Sultanov_6131/blob/main/Cats_and_Dogs_Model_4(.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle
from google.colab import files
files.upload()
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d tongpython/cat-and-dog
# !unzip -q 'cat-and-dog.zip'
# Out:
#      <input type="file" id="files-86f01a13-c3b1-41ca-aed7-7ebfaa97011c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86f01a13-c3b1-41ca-aed7-7ebfaa97011c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading cat-and-dog.zip to /content
#  97% 211M/218M [00:01<00:00, 192MB/s]
# 100% 218M/218M [00:01<00:00, 138MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

image_width, image_height = 100, 100 # Указываем разрешение для изображений к единому формату

directory_data_train= '/content/training_set/training_set' #Указываем путь к обучающей выборке 
directory_data_validation= '/content/test_set/test_set'  #Указываем путь к проверочной выборке 

# Сразу устанавливаем необходимые параметры

train_sample = 8000
validation_sample = 2000
epochs = 75
lot_size = 128  #batch_size 
if K.image_data_format() != 'channels_first':
     input_shape = (image_width, image_height, 3)
else:
     input_shape = (3, image_width, image_height)

# %%
pattern = Sequential() # Создание модели

# Первый слой нейросети
pattern.add(Conv2D(32, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Второй слой нейросети
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Третий слой нейросети
pattern.add(Conv2D(64, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Четвертый слой нейросети
pattern.add(Conv2D(128, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

#Aктивация, свертка, объединение, исключение
pattern.add(Flatten())
pattern.add(Dense(256))
pattern.add(Activation('relu'))
pattern.add(Dropout(0.5))
pattern.add(Dense(2)) # число классов
pattern.add(Activation('sigmoid'))

#Cкомпилируем модель с выбранными параметрами + метрика для оценки.
pattern.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Параметры аугментации
train_datagen = ImageDataGenerator(
    rescale=1. / 255, # коэффициент масштабирования
    shear_range = 1, # Интенсивность сдвига
    zoom_range=0.2, # Диапазон случайного увеличения
    width_shift_range=0.5, # Сдвиги
    height_shift_range=0.5,
    horizontal_flip=True,
    vertical_flip=True) # Произвольный поворот по горизонтали

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Предобработка обучающей выборки
train_processing = train_datagen.flow_from_directory(
    directory_data_train,
    target_size=(image_width, image_height), # Размер изображений
    batch_size=lot_size, #Размер пакетов данных 
    class_mode='categorical') # Режим класса 

#Предобработка тестовой выборки
validation_processing= test_datagen.flow_from_directory(
    directory_data_validation,
    target_size=(image_width, image_height),
    batch_size=lot_size,
    class_mode='categorical')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
history = pattern.fit(
    train_processing, # Помещаем обучающую выборку
    steps_per_epoch=train_sample // lot_size, #количество итераций пакета до того, как период обучения считается завершенным
    epochs=epochs, # Указываем количество эпох
    validation_data=validation_processing, # Помещаем проверочную выборку
    validation_steps=validation_sample  // lot_size) # Количество итераций на проверочном пакете данных
# Out:
# Epoch 1/75
# 62/62 [==============================] - 130s 2s/step - loss: 0.7015 - accuracy: 0.5191 - val_loss: 0.6832 - val_accuracy: 0.5318
# Epoch 2/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6912 - accuracy: 0.5549 - val_loss: 0.6817 - val_accuracy: 0.5667
# Epoch 3/75
# 62/62 [==============================] - 125s 2s/step - loss: 0.6739 - accuracy: 0.5837 - val_loss: 0.6658 - val_accuracy: 0.5714
# Epoch 4/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6680 - accuracy: 0.5856 - val_loss: 0.6514 - val_accuracy: 0.5958
# Epoch 5/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.6588 - accuracy: 0.6062 - val_loss: 0.6680 - val_accuracy: 0.5667
# Epoch 6/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.6537 - accuracy: 0.6153 - val_loss: 0.6352 - val_accuracy: 0.6104
# Epoch 7/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.6494 - accuracy: 0.6247 - val_loss: 0.6598 - val_accuracy: 0.5656
# Epoch 8/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.6343 - accuracy: 0.6473 - val_loss: 0.6568 - val_accuracy: 0.5932
# Epoch 9/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6278 - accuracy: 0.6445 - val_loss: 0.5866 - val_accuracy: 0.7052
# Epoch 10/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6325 - accuracy: 0.6440 - val_loss: 0.5953 - val_accuracy: 0.6859
# Epoch 11/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6268 - accuracy: 0.6502 - val_loss: 0.5899 - val_accuracy: 0.6922
# Epoch 12/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6209 - accuracy: 0.6557 - val_loss: 0.5805 - val_accuracy: 0.7047
# Epoch 13/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6199 - accuracy: 0.6631 - val_loss: 0.5737 - val_accuracy: 0.7099
# Epoch 14/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6235 - accuracy: 0.6542 - val_loss: 0.6075 - val_accuracy: 0.6589
# Epoch 15/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6143 - accuracy: 0.6582 - val_loss: 0.6076 - val_accuracy: 0.6500
# Epoch 16/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6066 - accuracy: 0.6662 - val_loss: 0.5575 - val_accuracy: 0.7120
# Epoch 17/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6052 - accuracy: 0.6711 - val_loss: 0.5584 - val_accuracy: 0.7302
# Epoch 18/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.6056 - accuracy: 0.6744 - val_loss: 0.5641 - val_accuracy: 0.7120
# Epoch 19/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5999 - accuracy: 0.6730 - val_loss: 0.5433 - val_accuracy: 0.7359
# Epoch 20/75
# 62/62 [==============================] - 129s 2s/step - loss: 0.5983 - accuracy: 0.6805 - val_loss: 0.7023 - val_accuracy: 0.5625
# Epoch 21/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5929 - accuracy: 0.6867 - val_loss: 0.5843 - val_accuracy: 0.6911
# Epoch 22/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5962 - accuracy: 0.6831 - val_loss: 0.6707 - val_accuracy: 0.6109
# Epoch 23/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5912 - accuracy: 0.6863 - val_loss: 0.5489 - val_accuracy: 0.7286
# Epoch 24/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5799 - accuracy: 0.6935 - val_loss: 0.7816 - val_accuracy: 0.5599
# Epoch 25/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5899 - accuracy: 0.6867 - val_loss: 0.5447 - val_accuracy: 0.7453
# Epoch 26/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5837 - accuracy: 0.6916 - val_loss: 0.5942 - val_accuracy: 0.6745
# Epoch 27/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5888 - accuracy: 0.6918 - val_loss: 0.5335 - val_accuracy: 0.7479
# Epoch 28/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5824 - accuracy: 0.6914 - val_loss: 0.6218 - val_accuracy: 0.6130
# Epoch 29/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5751 - accuracy: 0.7037 - val_loss: 0.5886 - val_accuracy: 0.6974
# Epoch 30/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5783 - accuracy: 0.6967 - val_loss: 0.5673 - val_accuracy: 0.7177
# Epoch 31/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5759 - accuracy: 0.6962 - val_loss: 0.6971 - val_accuracy: 0.6036
# Epoch 32/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5762 - accuracy: 0.6982 - val_loss: 0.6404 - val_accuracy: 0.6625
# Epoch 33/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5636 - accuracy: 0.7081 - val_loss: 0.6515 - val_accuracy: 0.6786
# Epoch 34/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5748 - accuracy: 0.7015 - val_loss: 0.5599 - val_accuracy: 0.7203
# Epoch 35/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5665 - accuracy: 0.7123 - val_loss: 0.5652 - val_accuracy: 0.7094
# Epoch 36/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5685 - accuracy: 0.7072 - val_loss: 0.5821 - val_accuracy: 0.6854
# Epoch 37/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5564 - accuracy: 0.7215 - val_loss: 0.6924 - val_accuracy: 0.6510
# Epoch 38/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5573 - accuracy: 0.7187 - val_loss: 0.6511 - val_accuracy: 0.6406
# Epoch 39/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5554 - accuracy: 0.7170 - val_loss: 0.5194 - val_accuracy: 0.7516
# Epoch 40/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5544 - accuracy: 0.7178 - val_loss: 0.5011 - val_accuracy: 0.7625
# Epoch 41/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5613 - accuracy: 0.7177 - val_loss: 0.5901 - val_accuracy: 0.6807
# Epoch 42/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5566 - accuracy: 0.7175 - val_loss: 0.6006 - val_accuracy: 0.6625
# Epoch 43/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5530 - accuracy: 0.7196 - val_loss: 0.5730 - val_accuracy: 0.6943
# Epoch 44/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5513 - accuracy: 0.7156 - val_loss: 0.5721 - val_accuracy: 0.7047
# Epoch 45/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5570 - accuracy: 0.7193 - val_loss: 0.5296 - val_accuracy: 0.7406
# Epoch 46/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5440 - accuracy: 0.7284 - val_loss: 0.6292 - val_accuracy: 0.6891
# Epoch 47/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5457 - accuracy: 0.7273 - val_loss: 0.5257 - val_accuracy: 0.7505
# Epoch 48/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5532 - accuracy: 0.7224 - val_loss: 0.5466 - val_accuracy: 0.7089
# Epoch 49/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5369 - accuracy: 0.7284 - val_loss: 0.5133 - val_accuracy: 0.7573
# Epoch 50/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5495 - accuracy: 0.7193 - val_loss: 0.5281 - val_accuracy: 0.7255
# Epoch 51/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5368 - accuracy: 0.7319 - val_loss: 0.4995 - val_accuracy: 0.7693
# Epoch 52/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5408 - accuracy: 0.7316 - val_loss: 0.4921 - val_accuracy: 0.7776
# Epoch 53/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5369 - accuracy: 0.7300 - val_loss: 0.4874 - val_accuracy: 0.7693
# Epoch 54/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5331 - accuracy: 0.7354 - val_loss: 0.5781 - val_accuracy: 0.6984
# Epoch 55/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5363 - accuracy: 0.7279 - val_loss: 0.5346 - val_accuracy: 0.7224
# Epoch 56/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5334 - accuracy: 0.7300 - val_loss: 0.5153 - val_accuracy: 0.7432
# Epoch 57/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5376 - accuracy: 0.7356 - val_loss: 0.6635 - val_accuracy: 0.6339
# Epoch 58/75
# 62/62 [==============================] - 125s 2s/step - loss: 0.5435 - accuracy: 0.7300 - val_loss: 0.5812 - val_accuracy: 0.7026
# Epoch 59/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5346 - accuracy: 0.7384 - val_loss: 0.4664 - val_accuracy: 0.7870
# Epoch 60/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5301 - accuracy: 0.7384 - val_loss: 0.5062 - val_accuracy: 0.7703
# Epoch 61/75
# 62/62 [==============================] - 128s 2s/step - loss: 0.5338 - accuracy: 0.7331 - val_loss: 0.7766 - val_accuracy: 0.6156
# Epoch 62/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5382 - accuracy: 0.7344 - val_loss: 0.4843 - val_accuracy: 0.7776
# Epoch 63/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5281 - accuracy: 0.7362 - val_loss: 0.7702 - val_accuracy: 0.6328
# Epoch 64/75
# 62/62 [==============================] - 127s 2s/step - loss: 0.5289 - accuracy: 0.7377 - val_loss: 0.5405 - val_accuracy: 0.7630
# Epoch 65/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5227 - accuracy: 0.7424 - val_loss: 0.5266 - val_accuracy: 0.7396
# Epoch 66/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5268 - accuracy: 0.7422 - val_loss: 0.4964 - val_accuracy: 0.7688
# Epoch 67/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5259 - accuracy: 0.7378 - val_loss: 0.4629 - val_accuracy: 0.7943
# Epoch 68/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5183 - accuracy: 0.7450 - val_loss: 0.5181 - val_accuracy: 0.7797
# Epoch 69/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5239 - accuracy: 0.7351 - val_loss: 0.4703 - val_accuracy: 0.7870
# Epoch 70/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5176 - accuracy: 0.7472 - val_loss: 0.6579 - val_accuracy: 0.6927
# Epoch 71/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5278 - accuracy: 0.7419 - val_loss: 0.4913 - val_accuracy: 0.7719
# Epoch 72/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5115 - accuracy: 0.7418 - val_loss: 0.5034 - val_accuracy: 0.7797
# Epoch 73/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5231 - accuracy: 0.7436 - val_loss: 0.4761 - val_accuracy: 0.7937
# Epoch 74/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5183 - accuracy: 0.7451 - val_loss: 0.7561 - val_accuracy: 0.6453
# Epoch 75/75
# 62/62 [==============================] - 126s 2s/step - loss: 0.5261 - accuracy: 0.7444 - val_loss: 0.5472 - val_accuracy: 0.7182

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy'],label='Точность на обучении')
plt.plot(history.history['val_accuracy'],label='Точность на валидации')
plt.title('Точность')
plt.figure()

plt.plot(history.history['loss'],label='Потери на обучении')
plt.plot(history.history['val_loss'],label='Потери на валидации')
plt.title('Потери')
plt.figure()

# %%
pattern.save('model_1') #Сохранение модели
# Out:
# INFO:tensorflow:Assets written to: model_1/assets

# %%
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, load_img
test_filenames = os.listdir("/content/gdrive/MyDrive/control_set")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
sample_test = test_df.head(30)
sample_test.head()
plt.figure(figsize=(12, 12))
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
  filename = row['filename']
  img = load_img("/content/gdrive/MyDrive/control_set/" + filename, target_size=(100, 100))
  test_image = image.load_img("/content/gdrive/MyDrive/control_set/" + filename,
                              target_size=(100, 100))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result =pattern.predict(test_image)
  if result[0][0] == 0:
    prediction = 'dog'
    category = prediction
  else:
    prediction = 'cat'
    category = prediction

  axes = plt.subplot(5, 6, index + 1)
  plt.imshow(img)
  plt.xlabel(format(category))
  axes.set_yticks([])
  axes.set_xticks([])
plt.tight_layout()
plt.show()
