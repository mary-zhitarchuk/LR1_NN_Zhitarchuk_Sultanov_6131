# %% [markdown]
# <a href="https://colab.research.google.com/github/mary-zhitarchuk/LR1_NN_Zhitarchuk_Sultanov_6131/blob/main/Cats_and_Dogs_Model_6(.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle
from google.colab import files
files.upload()
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d tongpython/cat-and-dog
# !unzip -q 'cat-and-dog.zip'
# Out:
#      <input type="file" id="files-c8af584a-bc68-425f-ba4a-151543001bac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8af584a-bc68-425f-ba4a-151543001bac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading cat-and-dog.zip to /content
#  98% 214M/218M [00:01<00:00, 131MB/s]
# 100% 218M/218M [00:01<00:00, 137MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

image_width, image_height = 100, 100 # Указываем разрешение для изображений к единому формату

directory_data_train= '/content/training_set/training_set' #Указываем путь к обучающей выборке 
directory_data_validation= '/content/test_set/test_set'  #Указываем путь к проверочной выборке 

# Сразу устанавливаем необходимые параметры

train_sample = 8000
validation_sample = 2000
epochs = 75
lot_size = 128  #batch_size 
if K.image_data_format() != 'channels_first':
     input_shape = (image_width, image_height, 3)
else:
     input_shape = (3, image_width, image_height)

# %%
pattern = Sequential() # Создание модели

# Первый слой нейросети
pattern.add(Conv2D(32, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Второй слой нейросети
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Третий слой нейросети
pattern.add(Conv2D(64, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Четвертый слой нейросети
pattern.add(Conv2D(128, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

#Aктивация, свертка, объединение, исключение
pattern.add(Flatten())
pattern.add(Dense(128))
pattern.add(Activation('relu'))
pattern.add(Dropout(0.5))
pattern.add(Dense(2)) # число классов
pattern.add(Activation('sigmoid'))

#Cкомпилируем модель с выбранными параметрами + метрика для оценки.
pattern.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Параметры аугментации
train_datagen = ImageDataGenerator(
    rescale=1. / 255, # коэффициент масштабирования
    shear_range = 0.5, # Интенсивность сдвига
    zoom_range = 0.2, # Диапазон случайного увеличения
    horizontal_flip=True,
    vertical_flip=True) # Произвольный поворот

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Предобработка обучающей выборки
train_processing = train_datagen.flow_from_directory(
    directory_data_train,
    target_size=(image_width, image_height), # Размер изображений
    batch_size=lot_size, #Размер пакетов данных 
    class_mode='categorical') # Режим класса 

#Предобработка тестовой выборки
validation_processing= test_datagen.flow_from_directory(
    directory_data_validation,
    target_size=(image_width, image_height),
    batch_size=lot_size,
    class_mode='categorical')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
history = pattern.fit(
    train_processing, # Помещаем обучающую выборку
    steps_per_epoch=train_sample // lot_size, #количество итераций пакета до того, как период обучения считается завершенным
    epochs=epochs, # Указываем количество эпох
    validation_data=validation_processing, # Помещаем проверочную выборку
    validation_steps=validation_sample  // lot_size) # Количество итераций на проверочном пакете данных
# Out:
# Epoch 1/75
# 62/62 [==============================] - 152s 2s/step - loss: 0.6953 - accuracy: 0.5214 - val_loss: 0.6862 - val_accuracy: 0.5193
# Epoch 2/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.6851 - accuracy: 0.5614 - val_loss: 0.6681 - val_accuracy: 0.6464
# Epoch 3/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.6592 - accuracy: 0.6181 - val_loss: 0.6465 - val_accuracy: 0.6021
# Epoch 4/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.6394 - accuracy: 0.6360 - val_loss: 0.5982 - val_accuracy: 0.6958
# Epoch 5/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.6288 - accuracy: 0.6532 - val_loss: 0.5890 - val_accuracy: 0.7089
# Epoch 6/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.6201 - accuracy: 0.6589 - val_loss: 0.5946 - val_accuracy: 0.6854
# Epoch 7/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5947 - accuracy: 0.6821 - val_loss: 0.6133 - val_accuracy: 0.6771
# Epoch 8/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5836 - accuracy: 0.6883 - val_loss: 0.5959 - val_accuracy: 0.6656
# Epoch 9/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5703 - accuracy: 0.7018 - val_loss: 0.5623 - val_accuracy: 0.7240
# Epoch 10/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5656 - accuracy: 0.7057 - val_loss: 0.5211 - val_accuracy: 0.7557
# Epoch 11/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.5586 - accuracy: 0.7135 - val_loss: 0.5372 - val_accuracy: 0.7391
# Epoch 12/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.5487 - accuracy: 0.7276 - val_loss: 0.5105 - val_accuracy: 0.7599
# Epoch 13/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5430 - accuracy: 0.7249 - val_loss: 0.5346 - val_accuracy: 0.7510
# Epoch 14/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5285 - accuracy: 0.7377 - val_loss: 0.4947 - val_accuracy: 0.7641
# Epoch 15/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.5323 - accuracy: 0.7356 - val_loss: 0.5733 - val_accuracy: 0.6927
# Epoch 16/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5268 - accuracy: 0.7413 - val_loss: 0.4969 - val_accuracy: 0.7661
# Epoch 17/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5045 - accuracy: 0.7495 - val_loss: 0.5968 - val_accuracy: 0.7443
# Epoch 18/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.5053 - accuracy: 0.7601 - val_loss: 0.5426 - val_accuracy: 0.7250
# Epoch 19/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.4960 - accuracy: 0.7547 - val_loss: 0.6025 - val_accuracy: 0.7469
# Epoch 20/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.4967 - accuracy: 0.7593 - val_loss: 0.5201 - val_accuracy: 0.7391
# Epoch 21/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.4898 - accuracy: 0.7612 - val_loss: 0.4573 - val_accuracy: 0.7870
# Epoch 22/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.4740 - accuracy: 0.7716 - val_loss: 0.4286 - val_accuracy: 0.8115
# Epoch 23/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.4787 - accuracy: 0.7683 - val_loss: 0.4921 - val_accuracy: 0.7563
# Epoch 24/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.4666 - accuracy: 0.7785 - val_loss: 0.5078 - val_accuracy: 0.7661
# Epoch 25/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.4671 - accuracy: 0.7787 - val_loss: 0.4515 - val_accuracy: 0.7818
# Epoch 26/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4464 - accuracy: 0.7875 - val_loss: 0.4757 - val_accuracy: 0.7896
# Epoch 27/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4636 - accuracy: 0.7832 - val_loss: 0.4335 - val_accuracy: 0.8104
# Epoch 28/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4421 - accuracy: 0.7923 - val_loss: 0.5837 - val_accuracy: 0.7063
# Epoch 29/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4371 - accuracy: 0.7956 - val_loss: 0.4439 - val_accuracy: 0.7859
# Epoch 30/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4259 - accuracy: 0.7999 - val_loss: 0.4307 - val_accuracy: 0.8016
# Epoch 31/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4296 - accuracy: 0.8040 - val_loss: 0.4208 - val_accuracy: 0.8094
# Epoch 32/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.4224 - accuracy: 0.8017 - val_loss: 0.7907 - val_accuracy: 0.6505
# Epoch 33/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4201 - accuracy: 0.8027 - val_loss: 0.3968 - val_accuracy: 0.8313
# Epoch 34/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4072 - accuracy: 0.8117 - val_loss: 0.5345 - val_accuracy: 0.7839
# Epoch 35/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.4036 - accuracy: 0.8133 - val_loss: 0.6003 - val_accuracy: 0.7542
# Epoch 36/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.4078 - accuracy: 0.8135 - val_loss: 0.4079 - val_accuracy: 0.8229
# Epoch 37/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3996 - accuracy: 0.8213 - val_loss: 0.5038 - val_accuracy: 0.7682
# Epoch 38/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3997 - accuracy: 0.8164 - val_loss: 0.3951 - val_accuracy: 0.8349
# Epoch 39/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3810 - accuracy: 0.8243 - val_loss: 0.3855 - val_accuracy: 0.8339
# Epoch 40/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3882 - accuracy: 0.8267 - val_loss: 0.5348 - val_accuracy: 0.7781
# Epoch 41/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.3705 - accuracy: 0.8389 - val_loss: 0.4053 - val_accuracy: 0.8318
# Epoch 42/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3749 - accuracy: 0.8361 - val_loss: 0.5377 - val_accuracy: 0.7734
# Epoch 43/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3766 - accuracy: 0.8320 - val_loss: 0.3922 - val_accuracy: 0.8417
# Epoch 44/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3798 - accuracy: 0.8303 - val_loss: 0.4245 - val_accuracy: 0.8370
# Epoch 45/75
# 62/62 [==============================] - 130s 2s/step - loss: 0.3569 - accuracy: 0.8423 - val_loss: 0.4799 - val_accuracy: 0.7719
# Epoch 46/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3539 - accuracy: 0.8440 - val_loss: 0.3786 - val_accuracy: 0.8438
# Epoch 47/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3483 - accuracy: 0.8427 - val_loss: 0.3895 - val_accuracy: 0.8359
# Epoch 48/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3461 - accuracy: 0.8442 - val_loss: 0.3881 - val_accuracy: 0.8380
# Epoch 49/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3442 - accuracy: 0.8502 - val_loss: 0.4232 - val_accuracy: 0.8172
# Epoch 50/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3424 - accuracy: 0.8484 - val_loss: 0.3648 - val_accuracy: 0.8557
# Epoch 51/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3285 - accuracy: 0.8562 - val_loss: 0.4033 - val_accuracy: 0.8234
# Epoch 52/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3340 - accuracy: 0.8511 - val_loss: 0.4016 - val_accuracy: 0.8344
# Epoch 53/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.3420 - accuracy: 0.8480 - val_loss: 0.4027 - val_accuracy: 0.8438
# Epoch 54/75
# 62/62 [==============================] - 133s 2s/step - loss: 0.3251 - accuracy: 0.8591 - val_loss: 0.3754 - val_accuracy: 0.8401
# Epoch 55/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.3298 - accuracy: 0.8619 - val_loss: 0.3791 - val_accuracy: 0.8521
# Epoch 56/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.3239 - accuracy: 0.8584 - val_loss: 0.4203 - val_accuracy: 0.8240
# Epoch 57/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3165 - accuracy: 0.8625 - val_loss: 0.4405 - val_accuracy: 0.8161
# Epoch 58/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3130 - accuracy: 0.8604 - val_loss: 0.3995 - val_accuracy: 0.8531
# Epoch 59/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3142 - accuracy: 0.8661 - val_loss: 0.3965 - val_accuracy: 0.8542
# Epoch 60/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3066 - accuracy: 0.8697 - val_loss: 0.3791 - val_accuracy: 0.8547
# Epoch 61/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3017 - accuracy: 0.8718 - val_loss: 0.4026 - val_accuracy: 0.8583
# Epoch 62/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3059 - accuracy: 0.8689 - val_loss: 0.3905 - val_accuracy: 0.8573
# Epoch 63/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.3028 - accuracy: 0.8675 - val_loss: 0.3941 - val_accuracy: 0.8615
# Epoch 64/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.2865 - accuracy: 0.8781 - val_loss: 0.3747 - val_accuracy: 0.8604
# Epoch 65/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.2981 - accuracy: 0.8723 - val_loss: 0.6574 - val_accuracy: 0.8318
# Epoch 66/75
# 62/62 [==============================] - 130s 2s/step - loss: 0.2917 - accuracy: 0.8741 - val_loss: 0.6698 - val_accuracy: 0.7682
# Epoch 67/75
# 62/62 [==============================] - 130s 2s/step - loss: 0.2949 - accuracy: 0.8736 - val_loss: 0.3649 - val_accuracy: 0.8510
# Epoch 68/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.2854 - accuracy: 0.8758 - val_loss: 0.3595 - val_accuracy: 0.8661
# Epoch 69/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.2790 - accuracy: 0.8846 - val_loss: 0.3987 - val_accuracy: 0.8568
# Epoch 70/75
# 62/62 [==============================] - 131s 2s/step - loss: 0.2768 - accuracy: 0.8865 - val_loss: 0.3648 - val_accuracy: 0.8594
# Epoch 71/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.2853 - accuracy: 0.8817 - val_loss: 0.3904 - val_accuracy: 0.8516
# Epoch 72/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.2789 - accuracy: 0.8818 - val_loss: 0.3868 - val_accuracy: 0.8672
# Epoch 73/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.2732 - accuracy: 0.8832 - val_loss: 0.4728 - val_accuracy: 0.8500
# Epoch 74/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.2885 - accuracy: 0.8765 - val_loss: 0.4046 - val_accuracy: 0.8432
# Epoch 75/75
# 62/62 [==============================] - 132s 2s/step - loss: 0.2757 - accuracy: 0.8842 - val_loss: 0.4014 - val_accuracy: 0.8542

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy'],label='Точность на обучении')
plt.plot(history.history['val_accuracy'],label='Точность на валидации')
plt.title('Точность')
plt.figure()

plt.plot(history.history['loss'],label='Потери на обучении')
plt.plot(history.history['val_loss'],label='Потери на валидации')
plt.title('Потери')
plt.figure()

# %%
pattern.save('model_1') #Сохранение модели
# Out:
# INFO:tensorflow:Assets written to: model_1/assets

# %%
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, load_img
test_filenames = os.listdir("/content/gdrive/MyDrive/control_set")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
sample_test = test_df.head(30)
sample_test.head()
plt.figure(figsize=(12, 12))
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
  filename = row['filename']
  img = load_img("/content/gdrive/MyDrive/control_set/" + filename, target_size=(100, 100))
  test_image = image.load_img("/content/gdrive/MyDrive/control_set/" + filename,
                              target_size=(100, 100))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result =pattern.predict(test_image)
  if result[0][0] == 0:
    prediction = 'dog'
    category = prediction
  else:
    prediction = 'cat'
    category = prediction

  axes = plt.subplot(5, 6, index + 1)
  plt.imshow(img)
  plt.xlabel(format(category))
  axes.set_yticks([])
  axes.set_xticks([])
plt.tight_layout()
plt.show()
