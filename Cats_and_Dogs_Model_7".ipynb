# %% [markdown]
# <a href="https://colab.research.google.com/github/mary-zhitarchuk/LR1_NN_Zhitarchuk_Sultanov_6131/blob/main/Cats_and_Dogs_Model_7%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle
from google.colab import files
files.upload()
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d tongpython/cat-and-dog
# !unzip -q 'cat-and-dog.zip'
# Out:
#      <input type="file" id="files-0152572e-018a-499d-b779-920e91e1de4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0152572e-018a-499d-b779-920e91e1de4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading cat-and-dog.zip to /content
#  95% 208M/218M [00:00<00:00, 233MB/s]
# 100% 218M/218M [00:00<00:00, 242MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

image_width, image_height = 100, 100 # Указываем разрешение для изображений к единому формату

directory_data_train= '/content/training_set/training_set' #Указываем путь к обучающей выборке 
directory_data_validation= '/content/test_set/test_set'  #Указываем путь к проверочной выборке 

# Сразу устанавливаем необходимые параметры

train_sample = 8000
validation_sample = 2000
epochs = 75
lot_size = 128  #batch_size 
if K.image_data_format() != 'channels_first':
     input_shape = (image_width, image_height, 3)
else:
     input_shape = (3, image_width, image_height)

# %%
pattern = Sequential() # Создание модели

# Первый слой нейросети
pattern.add(Conv2D(32, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Второй слой нейросети
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Третий слой нейросети
pattern.add(Conv2D(64, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Четвертый слой нейросети
pattern.add(Conv2D(128, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

#Aктивация, свертка, объединение, исключение
pattern.add(Flatten())
pattern.add(Dense(128))
pattern.add(Activation('relu'))
pattern.add(Dropout(0.5))
pattern.add(Dense(2)) # число классов
pattern.add(Activation('sigmoid'))

#Cкомпилируем модель с выбранными параметрами + метрика для оценки.
pattern.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Параметры аугментации
train_datagen = ImageDataGenerator(
    rescale=1. / 255, # коэффициент масштабирования
    shear_range = 0.5, # Интенсивность сдвига
    zoom_range = 0.2) # Диапазон случайного увеличения
    #horizontal_flip=True,
    #vertical_flip=True) # Произвольный поворот

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Предобработка обучающей выборки
train_processing = train_datagen.flow_from_directory(
    directory_data_train,
    target_size=(image_width, image_height), # Размер изображений
    batch_size=lot_size, #Размер пакетов данных 
    class_mode='categorical') # Режим класса 

#Предобработка тестовой выборки
validation_processing= test_datagen.flow_from_directory(
    directory_data_validation,
    target_size=(image_width, image_height),
    batch_size=lot_size,
    class_mode='categorical')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
history = pattern.fit(
    train_processing, # Помещаем обучающую выборку
    steps_per_epoch=train_sample // lot_size, #количество итераций пакета до того, как период обучения считается завершенным
    epochs=epochs, # Указываем количество эпох
    validation_data=validation_processing, # Помещаем проверочную выборку
    validation_steps=validation_sample  // lot_size) # Количество итераций на проверочном пакете данных
# Out:
# Epoch 1/75
# 62/62 [==============================] - 155s 2s/step - loss: 0.6941 - accuracy: 0.5407 - val_loss: 0.6939 - val_accuracy: 0.5010
# Epoch 2/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.6689 - accuracy: 0.6031 - val_loss: 0.6167 - val_accuracy: 0.6661
# Epoch 3/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.6307 - accuracy: 0.6421 - val_loss: 0.5843 - val_accuracy: 0.6943
# Epoch 4/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.5942 - accuracy: 0.6868 - val_loss: 0.6286 - val_accuracy: 0.6479
# Epoch 5/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.5701 - accuracy: 0.7017 - val_loss: 0.5372 - val_accuracy: 0.7276
# Epoch 6/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.5443 - accuracy: 0.7283 - val_loss: 0.5101 - val_accuracy: 0.7479
# Epoch 7/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.5277 - accuracy: 0.7391 - val_loss: 0.5107 - val_accuracy: 0.7406
# Epoch 8/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.5034 - accuracy: 0.7582 - val_loss: 0.4898 - val_accuracy: 0.7599
# Epoch 9/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.4756 - accuracy: 0.7768 - val_loss: 0.4942 - val_accuracy: 0.7583
# Epoch 10/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.4535 - accuracy: 0.7907 - val_loss: 0.5560 - val_accuracy: 0.7490
# Epoch 11/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.4331 - accuracy: 0.7990 - val_loss: 0.4481 - val_accuracy: 0.7859
# Epoch 12/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.4201 - accuracy: 0.8058 - val_loss: 0.4559 - val_accuracy: 0.8021
# Epoch 13/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.3989 - accuracy: 0.8169 - val_loss: 0.6186 - val_accuracy: 0.7286
# Epoch 14/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.3864 - accuracy: 0.8249 - val_loss: 0.4232 - val_accuracy: 0.8016
# Epoch 15/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.3670 - accuracy: 0.8378 - val_loss: 0.4326 - val_accuracy: 0.8031
# Epoch 16/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.3497 - accuracy: 0.8463 - val_loss: 0.4564 - val_accuracy: 0.8057
# Epoch 17/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.3370 - accuracy: 0.8527 - val_loss: 0.4335 - val_accuracy: 0.8005
# Epoch 18/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.3195 - accuracy: 0.8587 - val_loss: 0.4287 - val_accuracy: 0.8198
# Epoch 19/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.3003 - accuracy: 0.8682 - val_loss: 0.4949 - val_accuracy: 0.8016
# Epoch 20/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.2920 - accuracy: 0.8724 - val_loss: 0.4130 - val_accuracy: 0.8250
# Epoch 21/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.2776 - accuracy: 0.8790 - val_loss: 0.4506 - val_accuracy: 0.8219
# Epoch 22/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.2651 - accuracy: 0.8869 - val_loss: 0.4207 - val_accuracy: 0.8260
# Epoch 23/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.2499 - accuracy: 0.8922 - val_loss: 0.4630 - val_accuracy: 0.8245
# Epoch 24/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.2396 - accuracy: 0.9001 - val_loss: 0.4466 - val_accuracy: 0.8313
# Epoch 25/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.2270 - accuracy: 0.9059 - val_loss: 0.4742 - val_accuracy: 0.8281
# Epoch 26/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.2105 - accuracy: 0.9105 - val_loss: 0.4801 - val_accuracy: 0.8234
# Epoch 27/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.2014 - accuracy: 0.9167 - val_loss: 0.5923 - val_accuracy: 0.7937
# Epoch 28/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1911 - accuracy: 0.9199 - val_loss: 0.4417 - val_accuracy: 0.8297
# Epoch 29/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1727 - accuracy: 0.9281 - val_loss: 0.5098 - val_accuracy: 0.8219
# Epoch 30/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1774 - accuracy: 0.9293 - val_loss: 0.4839 - val_accuracy: 0.8391
# Epoch 31/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1712 - accuracy: 0.9328 - val_loss: 0.5707 - val_accuracy: 0.8219
# Epoch 32/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1624 - accuracy: 0.9369 - val_loss: 0.5505 - val_accuracy: 0.8234
# Epoch 33/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1555 - accuracy: 0.9364 - val_loss: 0.4755 - val_accuracy: 0.8370
# Epoch 34/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1359 - accuracy: 0.9466 - val_loss: 0.5750 - val_accuracy: 0.8292
# Epoch 35/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1363 - accuracy: 0.9462 - val_loss: 0.5633 - val_accuracy: 0.8286
# Epoch 36/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1412 - accuracy: 0.9452 - val_loss: 0.5381 - val_accuracy: 0.8359
# Epoch 37/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1186 - accuracy: 0.9528 - val_loss: 0.6849 - val_accuracy: 0.8130
# Epoch 38/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1277 - accuracy: 0.9511 - val_loss: 0.5807 - val_accuracy: 0.8396
# Epoch 39/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1105 - accuracy: 0.9558 - val_loss: 0.6091 - val_accuracy: 0.8271
# Epoch 40/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1268 - accuracy: 0.9509 - val_loss: 0.6398 - val_accuracy: 0.8333
# Epoch 41/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1049 - accuracy: 0.9605 - val_loss: 0.6054 - val_accuracy: 0.8313
# Epoch 42/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1066 - accuracy: 0.9599 - val_loss: 0.6665 - val_accuracy: 0.8453
# Epoch 43/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1040 - accuracy: 0.9610 - val_loss: 0.6257 - val_accuracy: 0.8432
# Epoch 44/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1014 - accuracy: 0.9590 - val_loss: 0.6064 - val_accuracy: 0.8432
# Epoch 45/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1031 - accuracy: 0.9623 - val_loss: 0.7075 - val_accuracy: 0.8161
# Epoch 46/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0878 - accuracy: 0.9707 - val_loss: 0.7669 - val_accuracy: 0.8469
# Epoch 47/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0911 - accuracy: 0.9689 - val_loss: 0.7967 - val_accuracy: 0.8286
# Epoch 48/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0953 - accuracy: 0.9648 - val_loss: 0.7084 - val_accuracy: 0.8427
# Epoch 49/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0876 - accuracy: 0.9665 - val_loss: 0.6720 - val_accuracy: 0.8255
# Epoch 50/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0846 - accuracy: 0.9705 - val_loss: 0.9013 - val_accuracy: 0.8250
# Epoch 51/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0823 - accuracy: 0.9703 - val_loss: 0.7713 - val_accuracy: 0.8380
# Epoch 52/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0762 - accuracy: 0.9719 - val_loss: 0.7332 - val_accuracy: 0.8307
# Epoch 53/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0794 - accuracy: 0.9728 - val_loss: 0.7552 - val_accuracy: 0.8385
# Epoch 54/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0781 - accuracy: 0.9740 - val_loss: 0.5532 - val_accuracy: 0.7979
# Epoch 55/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0766 - accuracy: 0.9736 - val_loss: 0.8351 - val_accuracy: 0.8198
# Epoch 56/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0708 - accuracy: 0.9748 - val_loss: 0.8891 - val_accuracy: 0.8359
# Epoch 57/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0653 - accuracy: 0.9764 - val_loss: 0.9399 - val_accuracy: 0.8266
# Epoch 58/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0710 - accuracy: 0.9721 - val_loss: 0.8673 - val_accuracy: 0.8464
# Epoch 59/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0857 - accuracy: 0.9680 - val_loss: 0.7445 - val_accuracy: 0.8339
# Epoch 60/75
# 62/62 [==============================] - 139s 2s/step - loss: 0.0645 - accuracy: 0.9758 - val_loss: 0.7495 - val_accuracy: 0.8406
# Epoch 61/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0718 - accuracy: 0.9754 - val_loss: 0.8900 - val_accuracy: 0.8042
# Epoch 62/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0713 - accuracy: 0.9763 - val_loss: 0.8513 - val_accuracy: 0.8401
# Epoch 63/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0762 - accuracy: 0.9749 - val_loss: 0.8018 - val_accuracy: 0.8469
# Epoch 64/75
# 62/62 [==============================] - 138s 2s/step - loss: 0.0600 - accuracy: 0.9807 - val_loss: 1.1709 - val_accuracy: 0.7417
# Epoch 65/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0705 - accuracy: 0.9747 - val_loss: 0.9374 - val_accuracy: 0.8260
# Epoch 66/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0728 - accuracy: 0.9769 - val_loss: 0.8311 - val_accuracy: 0.8484
# Epoch 67/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0608 - accuracy: 0.9780 - val_loss: 0.8871 - val_accuracy: 0.8286
# Epoch 68/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0633 - accuracy: 0.9785 - val_loss: 0.8865 - val_accuracy: 0.8438
# Epoch 69/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0627 - accuracy: 0.9773 - val_loss: 1.1427 - val_accuracy: 0.8224
# Epoch 70/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0580 - accuracy: 0.9822 - val_loss: 0.8645 - val_accuracy: 0.8448
# Epoch 71/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0652 - accuracy: 0.9770 - val_loss: 0.8938 - val_accuracy: 0.8458
# Epoch 72/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0641 - accuracy: 0.9792 - val_loss: 0.9464 - val_accuracy: 0.8427
# Epoch 73/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.0622 - accuracy: 0.9801 - val_loss: 0.8327 - val_accuracy: 0.8422
# Epoch 74/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0597 - accuracy: 0.9798 - val_loss: 1.0046 - val_accuracy: 0.8474
# Epoch 75/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.0602 - accuracy: 0.9793 - val_loss: 1.4744 - val_accuracy: 0.8391

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy'],label='Точность на обучении')
plt.plot(history.history['val_accuracy'],label='Точность на валидации')
plt.title('Точность')
plt.figure()

plt.plot(history.history['loss'],label='Потери на обучении')
plt.plot(history.history['val_loss'],label='Потери на валидации')
plt.title('Потери')
plt.figure()

# %%
pattern.save('model_1') #Сохранение модели
# Out:
# INFO:tensorflow:Assets written to: model_1/assets

# %%
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, load_img
test_filenames = os.listdir("/content/gdrive/MyDrive/control_set")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
sample_test = test_df.head(30)
sample_test.head()
plt.figure(figsize=(12, 12))
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
  filename = row['filename']
  img = load_img("/content/gdrive/MyDrive/control_set/" + filename, target_size=(100, 100))
  test_image = image.load_img("/content/gdrive/MyDrive/control_set/" + filename,
                              target_size=(100, 100))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result =pattern.predict(test_image)
  if result[0][0] == 0:
    prediction = 'dog'
    category = prediction
  else:
    prediction = 'cat'
    category = prediction

  axes = plt.subplot(5, 6, index + 1)
  plt.imshow(img)
  plt.xlabel(format(category))
  axes.set_yticks([])
  axes.set_xticks([])
plt.tight_layout()
plt.show()
