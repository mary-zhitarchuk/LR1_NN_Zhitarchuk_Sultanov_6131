# %% [markdown]
# <a href="https://colab.research.google.com/github/mary-zhitarchuk/LR1_NN_Zhitarchuk_Sultanov_6131/blob/main/Cats_and_Dogs_Model_1_(standart_4_all).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle
from google.colab import files
files.upload()
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d tongpython/cat-and-dog
# !unzip -q 'cat-and-dog.zip'
# Out:
#      <input type="file" id="files-12ef71f6-8fe8-4580-bdf6-d37e46aa8966" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12ef71f6-8fe8-4580-bdf6-d37e46aa8966">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading cat-and-dog.zip to /content
# 100% 217M/218M [00:07<00:00, 36.4MB/s]
# 100% 218M/218M [00:07<00:00, 30.4MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

image_width, image_height = 100, 100 # Указываем разрешение для изображений к единому формату

directory_data_train= '/content/training_set/training_set' #Указываем путь к обучающей выборке 
directory_data_validation= '/content/test_set/test_set'  #Указываем путь к проверочной выборке 

# Сразу устанавливаем необходимые параметры

train_sample = 8000
validation_sample = 2000
epochs = 75
lot_size = 128  #batch_size 
if K.image_data_format() != 'channels_first':
     input_shape = (image_width, image_height, 3)
else:
     input_shape = (3, image_width, image_height)

# %%
pattern = Sequential() # Создание модели

# Первый слой нейросети
pattern.add(Conv2D(32, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Второй слой нейросети
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Третий слой нейросети
pattern.add(Conv2D(64, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Четвертый слой нейросети
pattern.add(Conv2D(128, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

#Aктивация, свертка, объединение, исключение
pattern.add(Flatten())
pattern.add(Dense(128))
pattern.add(Activation('relu'))
pattern.add(Dropout(0.5))
pattern.add(Dense(2)) # число классов
pattern.add(Activation('sigmoid'))

#Cкомпилируем модель с выбранными параметрами + метрика для оценки.
pattern.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Параметры аугментации
train_datagen = ImageDataGenerator(
    rescale=1. / 255, # коэффициент масштабирования
    shear_range=0.2, # Интенсивность сдвига
    zoom_range=0.2, # Диапазон случайного увеличения
    horizontal_flip=True) # Произвольный поворот по горизонтали

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Предобработка обучающей выборки
train_processing = train_datagen.flow_from_directory(
    directory_data_train,
    target_size=(image_width, image_height), # Размер изображений
    batch_size=lot_size, #Размер пакетов данных 
    class_mode='categorical') # Режим класса 

#Предобработка тестовой выборки
validation_processing= test_datagen.flow_from_directory(
    directory_data_validation,
    target_size=(image_width, image_height),
    batch_size=lot_size,
    class_mode='categorical')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
history = pattern.fit(
    train_processing, # Помещаем обучающую выборку
    steps_per_epoch=train_sample // lot_size, #количество итераций пакета до того, как период обучения считается завершенным
    epochs=epochs, # Указываем количество эпох
    validation_data=validation_processing, # Помещаем проверочную выборку
    validation_steps=validation_sample  // lot_size) # Количество итераций на проверочном пакете данных
# Out:
# Epoch 1/75
# 62/62 [==============================] - 160s 3s/step - loss: 0.2266 - accuracy: 0.9049 - val_loss: 0.3658 - val_accuracy: 0.8734
# Epoch 2/75
# 62/62 [==============================] - 138s 2s/step - loss: 0.2246 - accuracy: 0.9039 - val_loss: 0.4777 - val_accuracy: 0.8271
# Epoch 3/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.2278 - accuracy: 0.9055 - val_loss: 0.3310 - val_accuracy: 0.8724
# Epoch 4/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.2225 - accuracy: 0.9068 - val_loss: 0.4118 - val_accuracy: 0.8620
# Epoch 5/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.2161 - accuracy: 0.9077 - val_loss: 0.3476 - val_accuracy: 0.8724
# Epoch 6/75
# 62/62 [==============================] - 139s 2s/step - loss: 0.2089 - accuracy: 0.9139 - val_loss: 0.3594 - val_accuracy: 0.8526
# Epoch 7/75
# 62/62 [==============================] - 138s 2s/step - loss: 0.2010 - accuracy: 0.9166 - val_loss: 0.3285 - val_accuracy: 0.8760
# Epoch 8/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.2088 - accuracy: 0.9175 - val_loss: 0.3772 - val_accuracy: 0.8656
# Epoch 9/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1894 - accuracy: 0.9207 - val_loss: 0.5033 - val_accuracy: 0.8333
# Epoch 10/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1989 - accuracy: 0.9188 - val_loss: 0.3752 - val_accuracy: 0.8682
# Epoch 11/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1846 - accuracy: 0.9236 - val_loss: 0.4458 - val_accuracy: 0.8495
# Epoch 12/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1851 - accuracy: 0.9267 - val_loss: 0.4152 - val_accuracy: 0.8516
# Epoch 13/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1755 - accuracy: 0.9255 - val_loss: 0.4725 - val_accuracy: 0.8750
# Epoch 14/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1886 - accuracy: 0.9214 - val_loss: 0.3792 - val_accuracy: 0.8573
# Epoch 15/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1783 - accuracy: 0.9250 - val_loss: 0.4336 - val_accuracy: 0.8724
# Epoch 16/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1676 - accuracy: 0.9293 - val_loss: 0.5184 - val_accuracy: 0.8724
# Epoch 17/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1657 - accuracy: 0.9339 - val_loss: 0.4665 - val_accuracy: 0.8885
# Epoch 18/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1682 - accuracy: 0.9325 - val_loss: 0.4462 - val_accuracy: 0.8656
# Epoch 19/75
# 62/62 [==============================] - 138s 2s/step - loss: 0.1682 - accuracy: 0.9335 - val_loss: 0.4241 - val_accuracy: 0.8750
# Epoch 20/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1634 - accuracy: 0.9361 - val_loss: 0.3759 - val_accuracy: 0.8755
# Epoch 21/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1582 - accuracy: 0.9354 - val_loss: 0.4343 - val_accuracy: 0.8708
# Epoch 22/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1690 - accuracy: 0.9327 - val_loss: 0.3880 - val_accuracy: 0.8719
# Epoch 23/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1598 - accuracy: 0.9339 - val_loss: 0.3757 - val_accuracy: 0.8755
# Epoch 24/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1547 - accuracy: 0.9370 - val_loss: 0.3862 - val_accuracy: 0.8901
# Epoch 25/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1597 - accuracy: 0.9372 - val_loss: 0.3716 - val_accuracy: 0.8745
# Epoch 26/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1593 - accuracy: 0.9389 - val_loss: 0.3699 - val_accuracy: 0.8750
# Epoch 27/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1421 - accuracy: 0.9439 - val_loss: 0.3988 - val_accuracy: 0.8854
# Epoch 28/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1498 - accuracy: 0.9387 - val_loss: 0.4441 - val_accuracy: 0.8823
# Epoch 29/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1520 - accuracy: 0.9401 - val_loss: 0.4802 - val_accuracy: 0.8776
# Epoch 30/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1469 - accuracy: 0.9440 - val_loss: 0.4006 - val_accuracy: 0.8755
# Epoch 31/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1421 - accuracy: 0.9449 - val_loss: 0.5424 - val_accuracy: 0.8823
# Epoch 32/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1514 - accuracy: 0.9420 - val_loss: 0.5271 - val_accuracy: 0.8609
# Epoch 33/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1446 - accuracy: 0.9450 - val_loss: 0.3548 - val_accuracy: 0.8807
# Epoch 34/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1288 - accuracy: 0.9507 - val_loss: 0.4486 - val_accuracy: 0.8818
# Epoch 35/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1427 - accuracy: 0.9421 - val_loss: 0.3891 - val_accuracy: 0.8828
# Epoch 36/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1405 - accuracy: 0.9434 - val_loss: 0.4317 - val_accuracy: 0.8755
# Epoch 37/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1359 - accuracy: 0.9464 - val_loss: 0.3963 - val_accuracy: 0.8854
# Epoch 38/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1330 - accuracy: 0.9507 - val_loss: 0.5114 - val_accuracy: 0.8656
# Epoch 39/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1344 - accuracy: 0.9487 - val_loss: 0.4004 - val_accuracy: 0.8844
# Epoch 40/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1328 - accuracy: 0.9524 - val_loss: 0.5492 - val_accuracy: 0.8776
# Epoch 41/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1311 - accuracy: 0.9481 - val_loss: 0.4811 - val_accuracy: 0.8807
# Epoch 42/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1308 - accuracy: 0.9505 - val_loss: 0.6976 - val_accuracy: 0.8198
# Epoch 43/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1407 - accuracy: 0.9468 - val_loss: 0.4938 - val_accuracy: 0.8792
# Epoch 44/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1266 - accuracy: 0.9537 - val_loss: 0.5930 - val_accuracy: 0.8661
# Epoch 45/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1299 - accuracy: 0.9526 - val_loss: 0.5778 - val_accuracy: 0.8797
# Epoch 46/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1251 - accuracy: 0.9515 - val_loss: 0.8001 - val_accuracy: 0.8464
# Epoch 47/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1351 - accuracy: 0.9506 - val_loss: 0.4934 - val_accuracy: 0.8849
# Epoch 48/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1298 - accuracy: 0.9532 - val_loss: 0.4075 - val_accuracy: 0.8682
# Epoch 49/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1332 - accuracy: 0.9493 - val_loss: 0.4135 - val_accuracy: 0.8672
# Epoch 50/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1227 - accuracy: 0.9563 - val_loss: 0.3972 - val_accuracy: 0.8865
# Epoch 51/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1267 - accuracy: 0.9510 - val_loss: 0.7175 - val_accuracy: 0.8839
# Epoch 52/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1243 - accuracy: 0.9507 - val_loss: 0.4587 - val_accuracy: 0.8776
# Epoch 53/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1273 - accuracy: 0.9546 - val_loss: 0.5435 - val_accuracy: 0.8599
# Epoch 54/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1292 - accuracy: 0.9530 - val_loss: 0.6137 - val_accuracy: 0.8766
# Epoch 55/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1296 - accuracy: 0.9525 - val_loss: 0.3894 - val_accuracy: 0.8755
# Epoch 56/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1262 - accuracy: 0.9507 - val_loss: 0.4789 - val_accuracy: 0.8729
# Epoch 57/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1330 - accuracy: 0.9518 - val_loss: 0.5355 - val_accuracy: 0.8792
# Epoch 58/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1122 - accuracy: 0.9570 - val_loss: 0.6314 - val_accuracy: 0.8917
# Epoch 59/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1234 - accuracy: 0.9542 - val_loss: 0.5964 - val_accuracy: 0.8745
# Epoch 60/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1291 - accuracy: 0.9534 - val_loss: 0.4329 - val_accuracy: 0.8823
# Epoch 61/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1265 - accuracy: 0.9532 - val_loss: 0.4595 - val_accuracy: 0.8786
# Epoch 62/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1279 - accuracy: 0.9552 - val_loss: 0.5403 - val_accuracy: 0.8813
# Epoch 63/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1175 - accuracy: 0.9557 - val_loss: 0.4558 - val_accuracy: 0.8708
# Epoch 64/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1257 - accuracy: 0.9533 - val_loss: 0.4547 - val_accuracy: 0.8766
# Epoch 65/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1226 - accuracy: 0.9568 - val_loss: 0.6214 - val_accuracy: 0.8646
# Epoch 66/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1191 - accuracy: 0.9563 - val_loss: 0.5908 - val_accuracy: 0.8687
# Epoch 67/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1282 - accuracy: 0.9511 - val_loss: 0.4970 - val_accuracy: 0.8771
# Epoch 68/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1320 - accuracy: 0.9526 - val_loss: 0.6171 - val_accuracy: 0.8823
# Epoch 69/75
# 62/62 [==============================] - 134s 2s/step - loss: 0.1334 - accuracy: 0.9532 - val_loss: 0.5657 - val_accuracy: 0.8844
# Epoch 70/75
# 62/62 [==============================] - 135s 2s/step - loss: 0.1236 - accuracy: 0.9572 - val_loss: 0.4704 - val_accuracy: 0.8802
# Epoch 71/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1257 - accuracy: 0.9518 - val_loss: 0.4440 - val_accuracy: 0.8813
# Epoch 72/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1371 - accuracy: 0.9501 - val_loss: 0.6724 - val_accuracy: 0.8875
# Epoch 73/75
# 62/62 [==============================] - 138s 2s/step - loss: 0.1260 - accuracy: 0.9534 - val_loss: 0.8645 - val_accuracy: 0.8276
# Epoch 74/75
# 62/62 [==============================] - 137s 2s/step - loss: 0.1246 - accuracy: 0.9528 - val_loss: 0.4862 - val_accuracy: 0.8870
# Epoch 75/75
# 62/62 [==============================] - 136s 2s/step - loss: 0.1076 - accuracy: 0.9599 - val_loss: 0.5749 - val_accuracy: 0.8531

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy'],label='Точность на обучении')
plt.plot(history.history['val_accuracy'],label='Точность на валидации')
plt.title('Точность')
plt.figure()

plt.plot(history.history['loss'],label='Потери на обучении')
plt.plot(history.history['val_loss'],label='Потери на валидации')
plt.title('Потери')
plt.figure()

# %%
pattern.save('model_1') #Сохранение модели
# Out:
# INFO:tensorflow:Assets written to: model_1/assets

# %%
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, load_img
test_filenames = os.listdir("/content/gdrive/MyDrive/control_set")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
sample_test = test_df.head(30)
sample_test.head()
plt.figure(figsize=(12, 12))
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
  filename = row['filename']
  img = load_img("/content/gdrive/MyDrive/control_set/" + filename, target_size=(100, 100))
  test_image = image.load_img("/content/gdrive/MyDrive/control_set/" + filename,
                              target_size=(100, 100))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result = pattern.predict(test_image)
  if result[0][0] == 0:
    prediction = 'dog'
    category = prediction
  else:
    prediction = 'cat'
    category = prediction

  axes = plt.subplot(5, 6, index + 1)
  plt.imshow(img)
  plt.xlabel(format(category))
  axes.set_yticks([])
  axes.set_xticks([])
plt.tight_layout()
plt.show()
