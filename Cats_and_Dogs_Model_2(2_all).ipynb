# %% [markdown]
# <a href="https://colab.research.google.com/github/mary-zhitarchuk/LR1_NN_Zhitarchuk_Sultanov_6131/blob/main/Cats_and_Dogs_Model_2(2_all).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle
from google.colab import files
files.upload()
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d tongpython/cat-and-dog
# !unzip -q 'cat-and-dog.zip'
# Out:
#      <input type="file" id="files-6a08e445-da85-46d3-b8e3-a45cb27184ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a08e445-da85-46d3-b8e3-a45cb27184ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# Downloading cat-and-dog.zip to /content
#  89% 194M/218M [00:01<00:00, 178MB/s]
# 100% 218M/218M [00:01<00:00, 190MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

image_width, image_height = 100, 100 # Указываем разрешение для изображений к единому формату

directory_data_train= '/content/training_set/training_set' #Указываем путь к обучающей выборке 
directory_data_validation= '/content/test_set/test_set'  #Указываем путь к проверочной выборке 

# Сразу устанавливаем необходимые параметры

train_sample = 8000
validation_sample = 2000
epochs = 75
lot_size = 128  #batch_size 
if K.image_data_format() != 'channels_first':
     input_shape = (image_width, image_height, 3)
else:
     input_shape = (3, image_width, image_height)

# %%
pattern = Sequential() # Создание модели

# Первый слой нейросети
pattern.add(Conv2D(32, (3, 3), input_shape=input_shape))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Второй слой нейросети
pattern.add(Conv2D(32, (3, 3)))
pattern.add(Activation('relu'))
pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Третий слой нейросети
#pattern.add(Conv2D(64, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(MaxPooling2D(pool_size=(2, 2)))

# Четвертый слой нейросети
#pattern.add(Conv2D(64, (3, 3)))
#pattern.add(Activation('relu'))
#pattern.add(MaxPooling2D(pool_size=(2, 2)))

#Aктивация, свертка, объединение, исключение
pattern.add(Flatten())
pattern.add(Dense(128))
pattern.add(Activation('relu'))
pattern.add(Dropout(0.5))
pattern.add(Dense(2)) # число классов
pattern.add(Activation('sigmoid'))

#Cкомпилируем модель с выбранными параметрами + метрика для оценки.
pattern.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Параметры аугментации
train_datagen = ImageDataGenerator(
    rescale=1. / 255, # коэффициент масштабирования
    shear_range=0.2, # Интенсивность сдвига
    zoom_range=0.2, # Диапазон случайного увеличения
    horizontal_flip=True) # Произвольный поворот по горизонтали

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
#Предобработка обучающей выборки
train_processing = train_datagen.flow_from_directory(
    directory_data_train,
    target_size=(image_width, image_height), # Размер изображений
    batch_size=lot_size, #Размер пакетов данных 
    class_mode='categorical') # Режим класса 

#Предобработка тестовой выборки
validation_processing= test_datagen.flow_from_directory(
    directory_data_validation,
    target_size=(image_width, image_height),
    batch_size=lot_size,
    class_mode='categorical')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
history = pattern.fit(
    train_processing, # Помещаем обучающую выборку
    steps_per_epoch=train_sample // lot_size, #количество итераций пакета до того, как период обучения считается завершенным
    epochs=epochs, # Указываем количество эпох
    validation_data=validation_processing, # Помещаем проверочную выборку
    validation_steps=validation_sample  // lot_size) # Количество итераций на проверочном пакете данных
# Out:
# Epoch 1/75
# 62/62 [==============================] - 124s 2s/step - loss: 0.8555 - accuracy: 0.5505 - val_loss: 0.6639 - val_accuracy: 0.5760
# Epoch 2/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.6817 - accuracy: 0.5978 - val_loss: 0.6399 - val_accuracy: 0.6630
# Epoch 3/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.6377 - accuracy: 0.6478 - val_loss: 0.5854 - val_accuracy: 0.7161
# Epoch 4/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.6070 - accuracy: 0.6750 - val_loss: 0.5799 - val_accuracy: 0.6901
# Epoch 5/75
# 62/62 [==============================] - 125s 2s/step - loss: 0.5871 - accuracy: 0.6901 - val_loss: 0.5416 - val_accuracy: 0.7307
# Epoch 6/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.5616 - accuracy: 0.7088 - val_loss: 0.5723 - val_accuracy: 0.6818
# Epoch 7/75
# 62/62 [==============================] - 124s 2s/step - loss: 0.5471 - accuracy: 0.7277 - val_loss: 0.5342 - val_accuracy: 0.7240
# Epoch 8/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.5274 - accuracy: 0.7371 - val_loss: 0.5177 - val_accuracy: 0.7490
# Epoch 9/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.5147 - accuracy: 0.7466 - val_loss: 0.5209 - val_accuracy: 0.7453
# Epoch 10/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.5011 - accuracy: 0.7549 - val_loss: 0.4817 - val_accuracy: 0.7760
# Epoch 11/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4945 - accuracy: 0.7598 - val_loss: 0.5355 - val_accuracy: 0.7156
# Epoch 12/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.4858 - accuracy: 0.7738 - val_loss: 0.4878 - val_accuracy: 0.7797
# Epoch 13/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4739 - accuracy: 0.7730 - val_loss: 0.4658 - val_accuracy: 0.7865
# Epoch 14/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4630 - accuracy: 0.7813 - val_loss: 0.4752 - val_accuracy: 0.7844
# Epoch 15/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.4499 - accuracy: 0.7870 - val_loss: 0.4453 - val_accuracy: 0.7906
# Epoch 16/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4375 - accuracy: 0.7990 - val_loss: 0.4496 - val_accuracy: 0.7875
# Epoch 17/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.4356 - accuracy: 0.7960 - val_loss: 0.4591 - val_accuracy: 0.7932
# Epoch 18/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.4258 - accuracy: 0.8065 - val_loss: 0.4516 - val_accuracy: 0.7984
# Epoch 19/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4194 - accuracy: 0.8145 - val_loss: 0.4998 - val_accuracy: 0.7672
# Epoch 20/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4094 - accuracy: 0.8111 - val_loss: 0.5541 - val_accuracy: 0.7448
# Epoch 21/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4076 - accuracy: 0.8158 - val_loss: 0.4802 - val_accuracy: 0.7885
# Epoch 22/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.4021 - accuracy: 0.8201 - val_loss: 0.4309 - val_accuracy: 0.8026
# Epoch 23/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.4027 - accuracy: 0.8221 - val_loss: 0.4434 - val_accuracy: 0.8010
# Epoch 24/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3929 - accuracy: 0.8226 - val_loss: 0.4799 - val_accuracy: 0.7812
# Epoch 25/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3839 - accuracy: 0.8312 - val_loss: 0.4324 - val_accuracy: 0.8073
# Epoch 26/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3806 - accuracy: 0.8279 - val_loss: 0.5241 - val_accuracy: 0.7641
# Epoch 27/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3874 - accuracy: 0.8266 - val_loss: 0.4545 - val_accuracy: 0.7917
# Epoch 28/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3787 - accuracy: 0.8370 - val_loss: 0.5293 - val_accuracy: 0.7599
# Epoch 29/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.3786 - accuracy: 0.8336 - val_loss: 0.4422 - val_accuracy: 0.8005
# Epoch 30/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3603 - accuracy: 0.8464 - val_loss: 0.4638 - val_accuracy: 0.7922
# Epoch 31/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3591 - accuracy: 0.8454 - val_loss: 0.4319 - val_accuracy: 0.8146
# Epoch 32/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3585 - accuracy: 0.8454 - val_loss: 0.4584 - val_accuracy: 0.7958
# Epoch 33/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.3467 - accuracy: 0.8510 - val_loss: 0.4534 - val_accuracy: 0.8167
# Epoch 34/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.3466 - accuracy: 0.8471 - val_loss: 0.4388 - val_accuracy: 0.8130
# Epoch 35/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.3378 - accuracy: 0.8611 - val_loss: 0.4428 - val_accuracy: 0.8193
# Epoch 36/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3422 - accuracy: 0.8548 - val_loss: 0.4414 - val_accuracy: 0.8188
# Epoch 37/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3452 - accuracy: 0.8551 - val_loss: 0.4409 - val_accuracy: 0.8182
# Epoch 38/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3293 - accuracy: 0.8615 - val_loss: 0.4385 - val_accuracy: 0.8182
# Epoch 39/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3231 - accuracy: 0.8593 - val_loss: 0.4594 - val_accuracy: 0.8068
# Epoch 40/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.3266 - accuracy: 0.8600 - val_loss: 0.4389 - val_accuracy: 0.8234
# Epoch 41/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3313 - accuracy: 0.8560 - val_loss: 0.4838 - val_accuracy: 0.8031
# Epoch 42/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3157 - accuracy: 0.8670 - val_loss: 0.4781 - val_accuracy: 0.8062
# Epoch 43/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3142 - accuracy: 0.8663 - val_loss: 0.4663 - val_accuracy: 0.8172
# Epoch 44/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3223 - accuracy: 0.8597 - val_loss: 0.4849 - val_accuracy: 0.8078
# Epoch 45/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3145 - accuracy: 0.8682 - val_loss: 0.4498 - val_accuracy: 0.7844
# Epoch 46/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3090 - accuracy: 0.8705 - val_loss: 0.4906 - val_accuracy: 0.7901
# Epoch 47/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3062 - accuracy: 0.8748 - val_loss: 0.4523 - val_accuracy: 0.8120
# Epoch 48/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3042 - accuracy: 0.8672 - val_loss: 0.4501 - val_accuracy: 0.8151
# Epoch 49/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3056 - accuracy: 0.8727 - val_loss: 0.4413 - val_accuracy: 0.8156
# Epoch 50/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2989 - accuracy: 0.8767 - val_loss: 0.4708 - val_accuracy: 0.8073
# Epoch 51/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2905 - accuracy: 0.8736 - val_loss: 0.4874 - val_accuracy: 0.8078
# Epoch 52/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.3026 - accuracy: 0.8781 - val_loss: 0.4632 - val_accuracy: 0.8141
# Epoch 53/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2970 - accuracy: 0.8776 - val_loss: 0.4762 - val_accuracy: 0.8057
# Epoch 54/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2907 - accuracy: 0.8816 - val_loss: 0.4708 - val_accuracy: 0.8240
# Epoch 55/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2873 - accuracy: 0.8780 - val_loss: 0.4641 - val_accuracy: 0.8208
# Epoch 56/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2826 - accuracy: 0.8851 - val_loss: 0.5393 - val_accuracy: 0.8073
# Epoch 57/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2822 - accuracy: 0.8798 - val_loss: 0.5117 - val_accuracy: 0.8135
# Epoch 58/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2753 - accuracy: 0.8826 - val_loss: 0.4790 - val_accuracy: 0.8188
# Epoch 59/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2773 - accuracy: 0.8869 - val_loss: 0.4689 - val_accuracy: 0.8031
# Epoch 60/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.2752 - accuracy: 0.8863 - val_loss: 0.5517 - val_accuracy: 0.8245
# Epoch 61/75
# 62/62 [==============================] - 124s 2s/step - loss: 0.2721 - accuracy: 0.8870 - val_loss: 0.4647 - val_accuracy: 0.8182
# Epoch 62/75
# 62/62 [==============================] - 124s 2s/step - loss: 0.2680 - accuracy: 0.8920 - val_loss: 0.4847 - val_accuracy: 0.8224
# Epoch 63/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2743 - accuracy: 0.8866 - val_loss: 0.5207 - val_accuracy: 0.8276
# Epoch 64/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2637 - accuracy: 0.8908 - val_loss: 0.5241 - val_accuracy: 0.7891
# Epoch 65/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2687 - accuracy: 0.8906 - val_loss: 0.5247 - val_accuracy: 0.8021
# Epoch 66/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2638 - accuracy: 0.8936 - val_loss: 0.4911 - val_accuracy: 0.8005
# Epoch 67/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2760 - accuracy: 0.8847 - val_loss: 0.5186 - val_accuracy: 0.8161
# Epoch 68/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2688 - accuracy: 0.8936 - val_loss: 0.4893 - val_accuracy: 0.8203
# Epoch 69/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2711 - accuracy: 0.8909 - val_loss: 0.4944 - val_accuracy: 0.8229
# Epoch 70/75
# 62/62 [==============================] - 122s 2s/step - loss: 0.2636 - accuracy: 0.8916 - val_loss: 0.4737 - val_accuracy: 0.8099
# Epoch 71/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.2683 - accuracy: 0.8901 - val_loss: 0.4582 - val_accuracy: 0.7995
# Epoch 72/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.2545 - accuracy: 0.8981 - val_loss: 0.5829 - val_accuracy: 0.8193
# Epoch 73/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.2548 - accuracy: 0.8944 - val_loss: 0.6237 - val_accuracy: 0.8146
# Epoch 74/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.2639 - accuracy: 0.8904 - val_loss: 0.5259 - val_accuracy: 0.8240
# Epoch 75/75
# 62/62 [==============================] - 123s 2s/step - loss: 0.2604 - accuracy: 0.8958 - val_loss: 0.5747 - val_accuracy: 0.8016

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy'],label='Точность на обучении')
plt.plot(history.history['val_accuracy'],label='Точность на валидации')
plt.title('Точность')
plt.figure()

plt.plot(history.history['loss'],label='Потери на обучении')
plt.plot(history.history['val_loss'],label='Потери на валидации')
plt.title('Потери')
plt.figure()

# %%
pattern.save('model_1') #Сохранение модели
# Out:
# INFO:tensorflow:Assets written to: model_1/assets

# %%
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, load_img
test_filenames = os.listdir("/content/gdrive/MyDrive/control_set")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
sample_test = test_df.head(30)
sample_test.head()
plt.figure(figsize=(12, 12))
plt.figure(figsize=(12, 12))
for index, row in sample_test.iterrows():
  filename = row['filename']
  img = load_img("/content/gdrive/MyDrive/control_set/" + filename, target_size=(100, 100))
  test_image = image.load_img("/content/gdrive/MyDrive/control_set/" + filename,
                              target_size=(100, 100))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result =pattern.predict(test_image)
  if result[0][0] == 0:
    prediction = 'dog'
    category = prediction
  else:
    prediction = 'cat'
    category = prediction

  axes = plt.subplot(5, 6, index + 1)
  plt.imshow(img)
  plt.xlabel(format(category))
  axes.set_yticks([])
  axes.set_xticks([])
plt.tight_layout()
plt.show()
